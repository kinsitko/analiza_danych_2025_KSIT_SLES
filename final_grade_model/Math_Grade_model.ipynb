# %%
from imports_bib import *
from import_data import load_kaggle_dataset
from config_data import config

# %%
df = load_kaggle_dataset(
    dataset_name=config["dataset_name"],
    zip_file_name=config["zip_file_name"],
    csv_file_name=config["csv_file_name"],
    data_path=config["data_path"]
)

print(df.head())
# Out:
# Dataset URL: https://www.kaggle.com/datasets/adilshamim8/math-students
# Pliki w ZIP: ['Math-Students.csv']
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
target = 'G3'
df = df.drop(columns=['G1', 'G2'])

X = df.drop(columns=[target])
y = df[target]

# %%
categorical_features = X.select_dtypes(include='object').columns.tolist()
numerical_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
preprocessor = ColumnTransformer([
    ('num', StandardScaler(), numerical_features),
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_features)
])


def select_features(X, y):
    pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('model', XGBRegressor(n_estimators=100, max_depth=5, learning_rate=0.1, random_state=42))
    ])
    pipe.fit(X, y)
    model = pipe.named_steps['model']
    X_preprocessed = pipe.named_steps['preprocessor'].transform(X)
    selector = SelectFromModel(model, prefit=True)
    return selector, X_preprocessed, pipe

selector, X_transformed, full_pipe = select_features(X, y)
X_selected = selector.transform(X_transformed)

# %%
feature_names = full_pipe.named_steps['preprocessor'].get_feature_names_out()
selected_mask = selector.get_support()
selected_features = feature_names[selected_mask]
print("Wybrane cechy:")
print(selected_features)
# Out:
# Wybrane cechy:
# ['num__failures' 'num__goout' 'num__absences' 'cat__sex_M'
#  'cat__Pstatus_T' 'cat__Fjob_other' 'cat__Fjob_teacher'
#  'cat__guardian_other' 'cat__schoolsup_yes' 'cat__higher_yes']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 400),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0)
    }
    model = XGBRegressor(**params, random_state=42)
    return -cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=3).mean()

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)
# Out:
# [I 2025-09-18 16:40:06,734] A new study created in memory with name: no-name-cad9a0a5-7278-465a-85d8-33f4b05bff90
# [I 2025-09-18 16:40:10,473] Trial 0 finished with value: 22.1050542195638 and parameters: {'n_estimators': 291, 'max_depth': 8, 'learning_rate': 0.1451573002643952, 'subsample': 0.8924698777352937, 'colsample_bytree': 0.5968394420965994}. Best is trial 0 with value: 22.1050542195638.
# [I 2025-09-18 16:40:11,469] Trial 1 finished with value: 15.856488227844238 and parameters: {'n_estimators': 149, 'max_depth': 3, 'learning_rate': 0.13678391588354952, 'subsample': 0.9481672489089241, 'colsample_bytree': 0.8546827613742233}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:12,927] Trial 2 finished with value: 19.79795265197754 and parameters: {'n_estimators': 243, 'max_depth': 4, 'learning_rate': 0.13686860423310085, 'subsample': 0.8552035650834694, 'colsample_bytree': 0.7373818235221237}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:16,978] Trial 3 finished with value: 23.687896728515625 and parameters: {'n_estimators': 324, 'max_depth': 9, 'learning_rate': 0.17518743664761682, 'subsample': 0.5486094168955047, 'colsample_bytree': 0.670774431070724}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:18,406] Trial 4 finished with value: 16.886685371398926 and parameters: {'n_estimators': 118, 'max_depth': 3, 'learning_rate': 0.22525050031230084, 'subsample': 0.6662101680216166, 'colsample_bytree': 0.9582176815085712}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:20,242] Trial 5 finished with value: 21.464558919270832 and parameters: {'n_estimators': 189, 'max_depth': 6, 'learning_rate': 0.07869122367236195, 'subsample': 0.8790987802627561, 'colsample_bytree': 0.9185415501416334}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:22,644] Trial 6 finished with value: 24.337819417317707 and parameters: {'n_estimators': 390, 'max_depth': 4, 'learning_rate': 0.29437001472615026, 'subsample': 0.8748511590648284, 'colsample_bytree': 0.9567560177518089}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:26,140] Trial 7 finished with value: 21.436978022257488 and parameters: {'n_estimators': 257, 'max_depth': 7, 'learning_rate': 0.05094995521200758, 'subsample': 0.8470979236887037, 'colsample_bytree': 0.9115342277622881}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:28,262] Trial 8 finished with value: 24.068979263305664 and parameters: {'n_estimators': 396, 'max_depth': 4, 'learning_rate': 0.25026571861801916, 'subsample': 0.8275471844878144, 'colsample_bytree': 0.5312175493787505}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:29,755] Trial 9 finished with value: 22.57332483927409 and parameters: {'n_estimators': 110, 'max_depth': 10, 'learning_rate': 0.2750319538807551, 'subsample': 0.6052649333956684, 'colsample_bytree': 0.8246958138695382}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:31,549] Trial 10 finished with value: 20.63991355895996 and parameters: {'n_estimators': 175, 'max_depth': 6, 'learning_rate': 0.09406109356761566, 'subsample': 0.9723936868045097, 'colsample_bytree': 0.8025313878185214}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:32,197] Trial 11 finished with value: 16.47677167256673 and parameters: {'n_estimators': 105, 'max_depth': 3, 'learning_rate': 0.21080350510366583, 'subsample': 0.6791582622857725, 'colsample_bytree': 0.8741899016865026}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:32,943] Trial 12 finished with value: 17.471523920694988 and parameters: {'n_estimators': 163, 'max_depth': 3, 'learning_rate': 0.2021265742789058, 'subsample': 0.6810537826054527, 'colsample_bytree': 0.8414445761476719}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:34,182] Trial 13 finished with value: 19.419422785441082 and parameters: {'n_estimators': 140, 'max_depth': 5, 'learning_rate': 0.11567277859510787, 'subsample': 0.7578982432650796, 'colsample_bytree': 0.7452195268354113}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:34,959] Trial 14 finished with value: 16.707928975423176 and parameters: {'n_estimators': 203, 'max_depth': 3, 'learning_rate': 0.18760950103361626, 'subsample': 0.9711296354991499, 'colsample_bytree': 0.8708620966214949}. Best is trial 1 with value: 15.856488227844238.
# [I 2025-09-18 16:40:35,858] Trial 15 finished with value: 15.429375330607096 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.02868744052405968, 'subsample': 0.7416229095200658, 'colsample_bytree': 0.9952522029659121}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:37,306] Trial 16 finished with value: 17.27090358734131 and parameters: {'n_estimators': 218, 'max_depth': 5, 'learning_rate': 0.03668435703135181, 'subsample': 0.7685425928818418, 'colsample_bytree': 0.9986142782924474}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:38,634] Trial 17 finished with value: 17.584017753601074 and parameters: {'n_estimators': 153, 'max_depth': 5, 'learning_rate': 0.057936508167590106, 'subsample': 0.7237896250844384, 'colsample_bytree': 0.9922267987955349}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:39,957] Trial 18 finished with value: 15.80546792348226 and parameters: {'n_estimators': 141, 'max_depth': 7, 'learning_rate': 0.012608490390738525, 'subsample': 0.7995752514208183, 'colsample_bytree': 0.6660055522361299}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:41,147] Trial 19 finished with value: 15.734583218892416 and parameters: {'n_estimators': 135, 'max_depth': 7, 'learning_rate': 0.013510520085296155, 'subsample': 0.7915443011026649, 'colsample_bytree': 0.6676311846683434}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:44,737] Trial 20 finished with value: 17.477532068888348 and parameters: {'n_estimators': 342, 'max_depth': 8, 'learning_rate': 0.02454759884450982, 'subsample': 0.6216122998614997, 'colsample_bytree': 0.6687635751769246}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:46,134] Trial 21 finished with value: 15.696584701538086 and parameters: {'n_estimators': 134, 'max_depth': 7, 'learning_rate': 0.01855680475447948, 'subsample': 0.7955924359261192, 'colsample_bytree': 0.6681665153139613}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:47,592] Trial 22 finished with value: 18.726128260294598 and parameters: {'n_estimators': 125, 'max_depth': 8, 'learning_rate': 0.07289101747293159, 'subsample': 0.7986587013004472, 'colsample_bytree': 0.6209834710955239}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:48,831] Trial 23 finished with value: 16.175607363382976 and parameters: {'n_estimators': 104, 'max_depth': 7, 'learning_rate': 0.0366018982172666, 'subsample': 0.7217521610679964, 'colsample_bytree': 0.7136739850594166}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:50,983] Trial 24 finished with value: 15.737035751342773 and parameters: {'n_estimators': 224, 'max_depth': 6, 'learning_rate': 0.016624269373848505, 'subsample': 0.7950208506547564, 'colsample_bytree': 0.7864280048697733}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:52,977] Trial 25 finished with value: 19.51144536336263 and parameters: {'n_estimators': 182, 'max_depth': 9, 'learning_rate': 0.10498392796479344, 'subsample': 0.729193773116413, 'colsample_bytree': 0.5578394392044979}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:54,341] Trial 26 finished with value: 16.872769037882488 and parameters: {'n_estimators': 128, 'max_depth': 6, 'learning_rate': 0.0509643944764996, 'subsample': 0.5081599014269862, 'colsample_bytree': 0.6126870019003324}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:56,179] Trial 27 finished with value: 19.056625366210938 and parameters: {'n_estimators': 161, 'max_depth': 7, 'learning_rate': 0.061719652812044515, 'subsample': 0.9140499582482499, 'colsample_bytree': 0.702113352988423}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:40:58,489] Trial 28 finished with value: 16.397300084431965 and parameters: {'n_estimators': 198, 'max_depth': 5, 'learning_rate': 0.03632595382259693, 'subsample': 0.8215823686528186, 'colsample_bytree': 0.6401831838779939}. Best is trial 15 with value: 15.429375330607096.
# [I 2025-09-18 16:41:01,772] Trial 29 finished with value: 15.618150075276693 and parameters: {'n_estimators': 282, 'max_depth': 8, 'learning_rate': 0.012529465382880533, 'subsample': 0.9064590480725633, 'colsample_bytree': 0.5685701666847246}. Best is trial 15 with value: 15.429375330607096.

# %%
final_model = XGBRegressor(**study.best_params, random_state=42)
final_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9952522029659121, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.02868744052405968,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# Ewaluacja
y_pred = final_model.predict(X_test)
print("MSE:", mean_squared_error(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R²:", r2_score(y_test, y_pred))
# Out:
# MSE: 19.284053802490234
# MAE: 3.3547215461730957
# R²: 0.06653594970703125

# %%
# Residual plot
sns.scatterplot(x=y_test, y=y_test - y_pred)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Rzeczywiste G3")
plt.ylabel("Błąd predykcji")
plt.title("Residual Plot")
plt.show()

# %%
# SHAP interpretacja

X_train_selected = pd.DataFrame(X_selected, columns=selected_features)
explainer = shap.Explainer(final_model, X_train_selected.astype(np.float64))
shap_values = explainer(X_train_selected.astype(np.float64), check_additivity=False)

shap.summary_plot(shap_values, X_train_selected, plot_type="bar")
shap.summary_plot(shap_values, X_train_selected)

# %%
# Zapis modelu
joblib.dump(final_model, 'xgb_g3_model.pkl')
# Out:
# ['xgb_g3_model.pkl']
